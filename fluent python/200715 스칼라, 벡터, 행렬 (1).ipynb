# %%
import sklearn
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### 벡터

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()
iris.data[0, :]
# Out:
# array([5.1, 3.5, 1.4, 0.2])

# %%
x1 = np.array([5.1, 3.5, 1.4, 0.2])
x2 = np.array([[5.1],[3.5],[1.4],[0.2]])

# %% [markdown]
# 사이킷런 패키지에서 벡터를 요구하는 경우에는 반드시 열 개수가 1개인 `2차원 배열객체`를 넣어야 한다. 예측 문제의 입력 데이터는 대부분 벡터로 표시한다

# %%
from sklearn.datasets import load_digits

digits = load_digits()
samples = [0, 10, 20, 30, 1, 11, 21, 31]
d = []
for i in range(8):
    d.append(digits.images[samples[i]])

plt.figure(figsize=(8,2))
for i in range(8):
    plt.subplot(1, 8, i+1)
    plt.imshow(d[i], interpolation='nearest', cmap=plt.cm.bone_r)
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    plt.title('image {}'.format(i+1))
    
plt.suptitle('number 0 1')
plt.tight_layout()
plt.show()

# %%
np.shape(d[0])
# Out:
# (8, 8)

# %%
v = []
for i in range(8):
    v.append(d[i].reshape(64,1))

plt.figure(figsize=(8,3))
for i in range(8):
    plt.subplot(1, 8, i+1)
    plt.imshow(v[i], aspect=0.4,
              interpolation='nearest', cmap=plt.cm.bone_r)
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    plt.title('vector {}'.format(i+1))

plt.suptitle('vectorize image', y =1.05)
plt.tight_layout(w_pad=7)
plt.show()

# %% [markdown]
# #### 행렬
# 복수의 차원을 가지는 데이터 레코드가 다시 여러 개 있는 경우에 데이터를 합쳐서 표기한 것.
# - 하나의 데이터 레코드 => 열 벡터
# - 복수의 데이터 레코드 => 행 벡터

# %% [markdown]
# 행렬을 표기할 때는 `ndarray` 객체를 사용한다.

# %%
A = np.array([[11,12,13],[21,22,23]])
A
# Out:
# array([[11, 12, 13],
#        [21, 22, 23]])

# %% [markdown]
# #### 텐서
# 같은 크기의 행렬이 여러 개 같이 묶여 있는 것.(`다차원 배열`)

# %%
from scipy import misc
img_rgb = misc.face()
img_rgb.shape
# Out:
# (768, 1024, 3)

# %%
plt.subplot(221)
plt.imshow(img_rgb, cmap=plt.cm.gray)
plt.axis('off')
plt.title('RGB color image')

plt.subplot(222)
plt.imshow(img_rgb[:,:,0], cmap=plt.cm.gray)
plt.axis('off')
plt.title('Red channel')
# Out:
# Text(0.5, 1.0, 'Red channel')
